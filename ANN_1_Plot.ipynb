# %% [markdown]
# ## **ANN 1 – Write a Python program to plot a few activation functions that are being used in neural networks.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# --- Activation Functions & Their Derivatives ---

def sigmoid(x):
    """Sigmoid activation function."""
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    """Derivative of the sigmoid function."""
    s = sigmoid(x)
    return s * (1 - s)

def relu(x):
    """Rectified Linear Unit (ReLU) activation function."""
    return np.maximum(0, x)

def relu_derivative(x):
    """Derivative of the ReLU function."""
    return np.where(x > 0, 1, 0)

def tanh(x):
    """Hyperbolic Tangent (tanh) activation function."""
    return np.tanh(x)

def tanh_derivative(x):
    """Derivative of the tanh function."""
    return 1 - np.tanh(x)**2

def leaky_relu(x, alpha=0.01):
    """Leaky ReLU activation function."""
    return np.where(x > 0, x, alpha * x)

def leaky_relu_derivative(x, alpha=0.01):
    """Derivative of the Leaky ReLU function."""
    return np.where(x > 0, 1, alpha)

# %%
# --- Plotting ---

def plot_activation_functions():
    """Plots various activation functions and their derivatives."""
    x = np.linspace(-5, 5, 200)
    
    plt.style.use('seaborn-v0_8-whitegrid')
    fig, axs = plt.subplots(2, 2, figsize=(14, 10))
    fig.suptitle('Activation Functions and Their Derivatives', fontsize=18)

    # Sigmoid: Outputs between 0 and 1. Good for binary classification outputs.
    # LaTeX formula: \sigma(x) = \frac{1}{1 + e^{-x}}
    axs[0, 0].plot(x, sigmoid(x), label='Sigmoid')
    axs[0, 0].plot(x, sigmoid_derivative(x), label="Sigmoid Derivative", linestyle='--')
    axs[0, 0].set_title('Sigmoid')
    axs[0, 0].legend()
    axs[0, 0].set_xlabel('Input')
    axs[0, 0].set_ylabel('Output')

    # ReLU: Simple and efficient. Avoids vanishing gradients. Default choice for hidden layers.
    # LaTeX formula: f(x) = \max(0, x)
    axs[0, 1].plot(x, relu(x), label='ReLU')
    axs[0, 1].plot(x, relu_derivative(x), label="ReLU Derivative", linestyle='--')
    axs[0, 1].set_title('ReLU')
    axs[0, 1].legend()
    axs[0, 1].set_xlabel('Input')
    axs[0, 1].set_ylabel('Output')

    # Tanh: Outputs between -1 and 1. Zero-centered, which can help in training.
    # LaTeX formula: \tanh(x) = \frac{e^{x} - e^{-x}}{e^{x} + e^{-x}}
    axs[1, 0].plot(x, tanh(x), label='Tanh')
    axs[1, 0].plot(x, tanh_derivative(x), label="Tanh Derivative", linestyle='--')
    axs[1, 0].set_title('Hyperbolic Tangent (Tanh)')
    axs[1, 0].legend()
    axs[1, 0].set_xlabel('Input')
    axs[1, 0].set_ylabel('Output')

    # Leaky ReLU: A variant of ReLU that allows a small gradient when the unit is not active.
    # LaTeX formula: f(x) = x \text{ if } x > 0, \text{ else } \alpha x
    axs[1, 1].plot(x, leaky_relu(x), label='Leaky ReLU')
    axs[1, 1].plot(x, leaky_relu_derivative(x), label="Leaky ReLU Derivative", linestyle='--')
    axs[1, 1].set_title('Leaky ReLU')
    axs[1, 1].legend()
    axs[1, 1].set_xlabel('Input')
    axs[1, 1].set_ylabel('Output')

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# %%
# Run the plot
plot_activation_functions()
